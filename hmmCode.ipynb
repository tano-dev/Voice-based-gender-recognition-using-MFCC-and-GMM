# %%
import os
import urllib.request 
import numpy
import scipy
import pandas
import sklearn
import hmmlearn

# %%
# !pip install hmmlearn pydub SpeechRecognition
# Out:
# Requirement already satisfied: hmmlearn in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.3.3)
# Requirement already satisfied: pydub in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.25.1)
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.14.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: numpy>=1.10 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from hmmlearn) (2.3.5)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from hmmlearn) (1.8.0)
# Requirement already satisfied: scipy>=0.19 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from hmmlearn) (1.16.3)
# Collecting typing-extensions (from SpeechRecognition)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Downloading speechrecognition-3.14.4-py3-none-any.whl (32.9 MB)
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/32.9 MB 9.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 4.7/32.9 MB 10.2 MB/s eta 0:00:03
#    -------- ------------------------------- 7.3/32.9 MB 10.8 MB/s eta 0:00:03
#    ------------ --------------------------- 10.0/32.9 MB 10.9 MB/s eta 0:00:03
#    -------------- ------------------------- 12.3/32.9 MB 11.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 14.7/32.9 MB 11.3 MB/s eta 0:00:02
#    -------------------- ------------------- 17.0/32.9 MB 11.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 19.4/32.9 MB 11.3 MB/s eta 0:00:02
#    -------------------------- ------------- 22.0/32.9 MB 11.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 24.4/32.9 MB 11.3 MB/s eta 0:00:01
#    -------------------------------- ------- 26.7/32.9 MB 11.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 29.1/32.9 MB 11.5 MB/s eta 0:00:01
#    -------------------------------------- - 31.5/32.9 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 32.9/32.9 MB 11.3 MB/s  0:00:03
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, SpeechRecognition
#
#    -------------------- ------------------- 1/2 [SpeechRecognition]
#    -------------------- ------------------- 1/2 [SpeechRecognition]
#    -------------------- ------------------- 1/2 [SpeechRecognition]
#    -------------------- ------------------- 1/2 [SpeechRecognition]
#    ---------------------------------------- 2/2 [SpeechRecognition]
#
# Successfully installed SpeechRecognition-3.14.4 typing-extensions-4.15.0

# %%
## Import files:
# hmmCode/DataManager.py
# hmmCode/ModelsTrainer.py
# hmmCode/GenderIdentifier.py

from hmmCode.DataManager import *
from hmmCode.ModelsTrainer import *
from hmmCode.GenderIdentifier import *

# %%
# get data
# data_manager = DataManager("SLR45.tgz")
# data_manager.manage()
# train models
models_trainer = ModelsTrainer("TrainingData/females", "TrainingData/males")
models_trainer.process()
# Out:
# PROCESSNG  TrainingData/females\f0001_us_f0001_00001.wav
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 6
#       1 # get data
#       2 # data_manager = DataManager("SLR45.tgz")
#       3 # data_manager.manage()
#       4 # train models
#       5 models_trainer = ModelsTrainer("TrainingData/females", "TrainingData/males")
# ----> 6 models_trainer.process()
#
# File c:\Users\ADMIN\Documents\Voice-based-gender-recognition-using-MFCC-and-GMM\hmmCode\ModelsTrainer.py:76, in ModelsTrainer.process(self)
#      73 females, males = self.get_file_paths(self.females_training_path,
#      74                                      self.males_training_path)
#      75 # collect voice features
# ---> 76 female_voice_features = self.collect_features(females)
#      77 male_voice_features   = self.collect_features(males)
#      78 # generate gaussian mixture models
#
# File c:\Users\ADMIN\Documents\Voice-based-gender-recognition-using-MFCC-and-GMM\hmmCode\ModelsTrainer.py:112, in ModelsTrainer.collect_features(self, files)
#     110 for file in files:
#     111     print("%5s %10s" % ("PROCESSNG ", file))
# --> 112     self.ffmpeg_silence_eliminator(file, file.split('.')[0] + "_without_silence.wav")
#     114     # extract MFCC & delta MFCC features from audio
#     115     try:
#
# File c:\Users\ADMIN\Documents\Voice-based-gender-recognition-using-MFCC-and-GMM\hmmCode\ModelsTrainer.py:44, in ModelsTrainer.ffmpeg_silence_eliminator(self, input_path, output_path)
#      42 # filter silence in mp3 file
#      43 filter_command = ["ffmpeg", "-i", input_path, "-af", "silenceremove=1:0:0.05:-1:1:-36dB", "-ac", "1", "-ss", "0","-t","90", output_path, "-y"]
# ---> 44 out = subprocess.Popen(filter_command, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
#      45 out.wait()
#      47 with_silence_duration = os.popen("ffprobe -i '" + input_path + "' -show_format -v quiet | sed -n 's/duration=//p'").read()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1028, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1024         if self.text_mode:
#    1025             self.stderr = io.TextIOWrapper(self.stderr,
#    1026                     encoding=encoding, errors=errors)
# -> 1028     self._execute_child(args, executable, preexec_fn, close_fds,
#    1029                         pass_fds, cwd, env,
#    1030                         startupinfo, creationflags, shell,
#    1031                         p2cread, p2cwrite,
#    1032                         c2pread, c2pwrite,
#    1033                         errread, errwrite,
#    1034                         restore_signals,
#    1035                         gid, gids, uid, umask,
#    1036                         start_new_session, process_group)
#    1037 except:
#    1038     # Cleanup if the child failed starting.
#    1039     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\subprocess.py:1540, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1538 # Start the process
#    1539 try:
# -> 1540     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1541                              # no special security
#    1542                              None, None,
#    1543                              int(not close_fds),
#    1544                              creationflags,
#    1545                              env,
#    1546                              cwd,
#    1547                              startupinfo)
#    1548 finally:
#    1549     # Child is launched. Close the parent's copy of those pipe
#    1550     # handles that only the child should have open.  You need
#    (...)   1553     # pipe will not close when the child process exits and the
#    1554     # ReadFile will hang.
#    1555     self._close_pipe_fds(p2cread, p2cwrite,
#    1556                          c2pread, c2pwrite,
#    1557                          errread, errwrite)
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified

# %%
gender_identifier = GenderIdentifier("TestingData/females", "TestingData/males", "females.gmm", "males.gmm")
gender_identifier.process()
# Out:
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# Processing 988 files...
# --> TESTING        : f0001_us_f0001_00295.wav
# + FEMALE SCORE     : 3.493
# + MALE SCORE       : 2.31
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00296.wav
# + FEMALE SCORE     : 7.587
# + MALE SCORE       : 6.216
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00297.wav
# + FEMALE SCORE     : 6.673
# + MALE SCORE       : 6.006
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00298.wav
# + FEMALE SCORE     : 5.508
# + MALE SCORE       : 4.346
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00299.wav
# + FEMALE SCORE     : 4.387
# + MALE SCORE       : 3.446
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00300.wav
# + FEMALE SCORE     : 4.353
# + MALE SCORE       : 3.389
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00301.wav
# + FEMALE SCORE     : 4.192
# + MALE SCORE       : 3.123
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00414.wav
# + FEMALE SCORE     : 3.65
# + MALE SCORE       : 2.838
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00415.wav
# + FEMALE SCORE     : 3.963
# + MALE SCORE       : 2.776
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00416.wav
# + FEMALE SCORE     : 2.828
# + MALE SCORE       : 2.41
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00417.wav
# + FEMALE SCORE     : 4.078
# + MALE SCORE       : 2.694
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00418.wav
# + FEMALE SCORE     : 5.476
# + MALE SCORE       : 3.894
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00419.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 2.901
# + MALE SCORE       : 1.761
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00420.wav
# + FEMALE SCORE     : 1.939
# + MALE SCORE       : 0.528
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00421.wav
# + FEMALE SCORE     : 2.973
# + MALE SCORE       : 2.206
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00422.wav
# + FEMALE SCORE     : 5.901
# + MALE SCORE       : 4.878
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00423.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 4.274
# + MALE SCORE       : 3.153
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00424.wav
# + FEMALE SCORE     : 3.133
# + MALE SCORE       : 1.692
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00425.wav
# + FEMALE SCORE     : 4.294
# + MALE SCORE       : 3.099
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00426.wav
# + FEMALE SCORE     : 3.269
# + MALE SCORE       : 2.365
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00427.wav
# + FEMALE SCORE     : 5.586
# + MALE SCORE       : 4.896
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00428.wav
# + FEMALE SCORE     : 4.513
# + MALE SCORE       : 3.097
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00429.wav
# + FEMALE SCORE     : 2.59
# + MALE SCORE       : 1.487
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00430.wav
# + FEMALE SCORE     : 4.976
# + MALE SCORE       : 3.783
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00431.wav
# + FEMALE SCORE     : 2.77
# + MALE SCORE       : 1.682
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00432.wav
# + FEMALE SCORE     : 2.97
# + MALE SCORE       : 2.036
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00433.wav
# + FEMALE SCORE     : 4.63
# + MALE SCORE       : 4.435
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00434.wav
# + FEMALE SCORE     : 2.455
# + MALE SCORE       : 1.259
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00435.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 3.901
# + MALE SCORE       : 2.761
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00436.wav
# + FEMALE SCORE     : 5.639
# + MALE SCORE       : 4.618
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00437.wav
# + FEMALE SCORE     : 3.175
# + MALE SCORE       : 2.068
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00438.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 1.472
# + MALE SCORE       : 0.27
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00439.wav
# + FEMALE SCORE     : 5.911
# + MALE SCORE       : 4.595
# ...
# + MALE SCORE       : -0.756
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00125.wav
# + FEMALE SCORE     : 0.34
# + MALE SCORE       : 0.774
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00126.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 2.803
# + MALE SCORE       : 2.732
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00127.wav
# + FEMALE SCORE     : 4.352
# + MALE SCORE       : 4.553
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00128.wav
# + FEMALE SCORE     : 2.835
# + MALE SCORE       : 2.236
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00129.wav
# + FEMALE SCORE     : 3.115
# + MALE SCORE       : 2.744
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00130.wav
# + FEMALE SCORE     : 1.982
# + MALE SCORE       : 1.995
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00131.wav
# + FEMALE SCORE     : 4.953
# + MALE SCORE       : 4.813
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00132.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 4.367
# + MALE SCORE       : 4.163
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00133.wav
# + FEMALE SCORE     : 9.301
# + MALE SCORE       : 10.029
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00134.wav
# + FEMALE SCORE     : 8.613
# + MALE SCORE       : 7.779
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00135.wav
# + FEMALE SCORE     : 8.564
# + MALE SCORE       : 8.015
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00136.wav
# + FEMALE SCORE     : 4.973
# + MALE SCORE       : 5.394
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00137.wav
# + FEMALE SCORE     : 6.917
# + MALE SCORE       : 6.931
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00138.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 6.97
# + MALE SCORE       : 7.024
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00139.wav
# + FEMALE SCORE     : 4.742
# + MALE SCORE       : 4.12
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00140.wav
# + FEMALE SCORE     : 3.319
# + MALE SCORE       : 3.664
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00141.wav
# + FEMALE SCORE     : 3.817
# + MALE SCORE       : 3.546
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00142.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 4.078
# + MALE SCORE       : 3.906
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00143.wav
# + FEMALE SCORE     : 7.74
# + MALE SCORE       : 7.946
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00144.wav
# + FEMALE SCORE     : 6.058
# + MALE SCORE       : 6.567
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00145.wav
# + FEMALE SCORE     : 7.666
# + MALE SCORE       : 7.796
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00146.wav
# + FEMALE SCORE     : 4.881
# + MALE SCORE       : 5.175
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00147.wav
# + FEMALE SCORE     : 8.919
# + MALE SCORE       : 8.304
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00148.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 5.292
# + MALE SCORE       : 5.562
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00149.wav
# + FEMALE SCORE     : 3.135
# + MALE SCORE       : 3.562
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00150.wav
# + FEMALE SCORE     : 7.057
# + MALE SCORE       : 5.738
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00151.wav
# + FEMALE SCORE     : 8.181
# + MALE SCORE       : 7.712
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00152.wav
# + FEMALE SCORE     : 7.177
# + MALE SCORE       : 7.472
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00153.wav
# + FEMALE SCORE     : 7.496
# + MALE SCORE       : 6.932
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00154.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 9.064
# + MALE SCORE       : 8.32
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00155.wav
# + FEMALE SCORE     : 3.691
# + MALE SCORE       : 3.557
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00156.wav
# + FEMALE SCORE     : 9.506
# + MALE SCORE       : 9.916
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00157.wav
# + FEMALE SCORE     : 6.604
# + MALE SCORE       : 6.835
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00158.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 5.895
# + MALE SCORE       : 5.86
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00159.wav
# + FEMALE SCORE     : 5.027
# + MALE SCORE       : 4.621
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00160.wav
# + FEMALE SCORE     : 6.188
# + MALE SCORE       : 5.97
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00161.wav
# + FEMALE SCORE     : 6.803
# + MALE SCORE       : 7.088
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00162.wav
# + FEMALE SCORE     : 2.636
# + MALE SCORE       : 2.645
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00163.wav
# + FEMALE SCORE     : 3.083
# + MALE SCORE       : 3.057
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00164.wav
# + FEMALE SCORE     : 6.24
# + MALE SCORE       : 6.262
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00165.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 6.285
# + MALE SCORE       : 5.573
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00166.wav
# + FEMALE SCORE     : 8.848
# + MALE SCORE       : 9.362
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00167.wav
# + FEMALE SCORE     : 7.621
# + MALE SCORE       : 7.995
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00168.wav
# + FEMALE SCORE     : 5.127
# + MALE SCORE       : 4.817
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00169.wav
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# WARNING:root:frame length (800) is greater than FFT size (512), frame will be truncated. Increase NFFT to avoid.
# + FEMALE SCORE     : 7.41
# + MALE SCORE       : 7.438
# + EXPECTATION      : male
# + IDENTIFICATION   : male
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00170.wav
# + FEMALE SCORE     : 7.413
# + MALE SCORE       : 7.074
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00171.wav
# + FEMALE SCORE     : 8.209
# + MALE SCORE       : 7.909
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#     [MISMATCH] Expected: male, Got: female
# ----------------------------------------------------
# *** Accuracy = 94.636% ***
