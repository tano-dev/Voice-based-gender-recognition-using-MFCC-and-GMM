# %%
import os
import urllib.request 
import numpy
import scipy
import pandas
import sklearn
import hmmlearn

# %%
# !pip install pandas hmmlearn pydub SpeechRecognition python_speech_features librosa soundfile keras tensorflow
# Out:
# Requirement already satisfied: pandas in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: hmmlearn in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.3.3)
# Requirement already satisfied: pydub in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.25.1)
# Requirement already satisfied: SpeechRecognition in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (3.14.4)
# Requirement already satisfied: python_speech_features in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.6)
# Requirement already satisfied: librosa in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.11.0)
# Requirement already satisfied: soundfile in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (0.13.1)
# Requirement already satisfied: keras in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (3.13.0)
# Requirement already satisfied: tensorflow in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (2.20.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from hmmlearn) (1.8.0)
# Requirement already satisfied: scipy>=0.19 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from hmmlearn) (1.16.3)
# Requirement already satisfied: typing-extensions in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from SpeechRecognition) (4.15.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (0.63.1)
# Requirement already satisfied: joblib>=1.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (5.2.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (1.0.0)
# Requirement already satisfied: lazy_loader>=0.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: cffi>=1.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: absl-py in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (2.3.1)
# Requirement already satisfied: rich in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from keras) (25.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (6.33.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.10)
# Requirement already satisfied: pillow in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: pycparser in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from cffi>=1.0->soundfile) (2.23)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from numba>=0.51.0->librosa) (0.46.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from pooch>=1.1->librosa) (4.5.1)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.6.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\documents\voice-based-gender-recognition-using-mfcc-and-gmm\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
## Import files:
# hmmCode/DataManager.py
# hmmCode/ModelsTrainer.py
# hmmCode/GenderIdentifier.py

from nnCode.DataManager import *
from nnCode.ModelsTrainer import *
from nnCode.GenderIdentifier import *

# %%
# get data
# data_manager = DataManager("SLR45.tgz")
# data_manager.manage()
# train models
models_trainer = ModelsTrainer("TrainingData/females", "TrainingData/males")
models_trainer.process()
# Out:
# --> STARTING TRAINING FOR: female
# Processing female file 10/1164
# Processing female file 20/1164
# Processing female file 30/1164
# Processing female file 40/1164
# Processing female file 50/1164
# Processing female file 60/1164
# Processing female file 70/1164
# Processing female file 80/1164
# Processing female file 90/1164
# Processing female file 100/1164
# Processing female file 110/1164
# Processing female file 120/1164
# Processing female file 130/1164
# Processing female file 140/1164
# Processing female file 150/1164
# Processing female file 160/1164
# Processing female file 170/1164
# Processing female file 180/1164
# Processing female file 190/1164
# Processing female file 200/1164
# Processing female file 210/1164
# Processing female file 220/1164
# Processing female file 230/1164
# Processing female file 240/1164
# Processing female file 250/1164
# Processing female file 260/1164
# Processing female file 270/1164
# Processing female file 280/1164
# Processing female file 290/1164
# Processing female file 300/1164
# Processing female file 310/1164
# Processing female file 320/1164
# Processing female file 330/1164
# Processing female file 340/1164
# Processing female file 350/1164
# Processing female file 360/1164
# Processing female file 370/1164
# Processing female file 380/1164
# Processing female file 390/1164
# Processing female file 400/1164
# Processing female file 410/1164
# Processing female file 420/1164
# Processing female file 430/1164
# Processing female file 440/1164
# Processing female file 450/1164
# Processing female file 460/1164
# Processing female file 470/1164
# Processing female file 480/1164
# Processing female file 490/1164
# Processing female file 500/1164
# Processing female file 510/1164
# Processing female file 520/1164
# Processing female file 530/1164
# Processing female file 540/1164
# Processing female file 550/1164
# Processing female file 560/1164
# Processing female file 570/1164
# Processing female file 580/1164
# Processing female file 590/1164
# Processing female file 600/1164
# Processing female file 610/1164
# Processing female file 620/1164
# Processing female file 630/1164
# Processing female file 640/1164
# Processing female file 650/1164
# Processing female file 660/1164
# Processing female file 670/1164
# Processing female file 680/1164
# Processing female file 690/1164
# Processing female file 700/1164
# Processing female file 710/1164
# Processing female file 720/1164
# Processing female file 730/1164
# Processing female file 740/1164
# Processing female file 750/1164
# Processing female file 760/1164
# Processing female file 770/1164
# Processing female file 780/1164
# Processing female file 790/1164
# Processing female file 800/1164
# Processing female file 810/1164
# Processing female file 820/1164
# Processing female file 830/1164
# Processing female file 840/1164
# Processing female file 850/1164
# Processing female file 860/1164
# Processing female file 870/1164
# Processing female file 880/1164
# Processing female file 890/1164
# Processing female file 900/1164
# Processing female file 910/1164
# Processing female file 920/1164
# Processing female file 930/1164
# Processing female file 940/1164
# Processing female file 950/1164
# Processing female file 960/1164
# Processing female file 970/1164
# Processing female file 980/1164
# Processing female file 990/1164
# Processing female file 1000/1164
# Processing female file 1010/1164
# Processing female file 1020/1164
# Processing female file 1030/1164
# Processing female file 1040/1164
# Processing female file 1050/1164
# Processing female file 1060/1164
# Processing female file 1070/1164
# Processing female file 1080/1164
# Processing female file 1090/1164
# Processing female file 1100/1164
# Processing female file 1110/1164
# Processing female file 1120/1164
# Processing female file 1130/1164
# Processing female file 1140/1164
# Processing female file 1150/1164
# Processing female file 1160/1164
# Total features shape for female: (90464, 39)
# Fitting GMM for female (this may still take a moment)...
# SAVED MODEL: c:\Users\ADMIN\Documents\Voice-based-gender-recognition-using-MFCC-and-GMM\nnCode\models\females.nn
# --> STARTING TRAINING FOR: male
# Processing male file 10/804
# Processing male file 20/804
# Processing male file 30/804
# Processing male file 40/804
# Processing male file 50/804
# Processing male file 60/804
# Processing male file 70/804
# Processing male file 80/804
# Processing male file 90/804
# Processing male file 100/804
# Processing male file 110/804
# Processing male file 120/804
# Processing male file 130/804
# Processing male file 140/804
# Processing male file 150/804
# Processing male file 160/804
# Processing male file 170/804
# Processing male file 180/804
# Processing male file 190/804
# Processing male file 200/804
# Processing male file 210/804
# Processing male file 220/804
# Processing male file 230/804
# Processing male file 240/804
# Processing male file 250/804
# Processing male file 260/804
# Processing male file 270/804
# Processing male file 280/804
# Processing male file 290/804
# Processing male file 300/804
# Processing male file 310/804
# Processing male file 320/804
# Processing male file 330/804
# Processing male file 340/804
# Processing male file 350/804
# Processing male file 360/804
# Processing male file 370/804
# Processing male file 380/804
# Processing male file 390/804
# Processing male file 400/804
# Processing male file 410/804
# Processing male file 420/804
# Processing male file 430/804
# Processing male file 440/804
# Processing male file 450/804
# Processing male file 460/804
# Processing male file 470/804
# Processing male file 480/804
# Processing male file 490/804
# Processing male file 500/804
# Processing male file 510/804
# Processing male file 520/804
# Processing male file 530/804
# Processing male file 540/804
# Processing male file 550/804
# Processing male file 560/804
# Processing male file 570/804
# Processing male file 580/804
# Processing male file 590/804
# Processing male file 600/804
# Processing male file 610/804
# Processing male file 620/804
# Processing male file 630/804
# Processing male file 640/804
# Processing male file 650/804
# Processing male file 660/804
# Processing male file 670/804
# Processing male file 680/804
# Processing male file 690/804
# Processing male file 700/804
# Processing male file 710/804
# Processing male file 720/804
# Processing male file 730/804
# Processing male file 740/804
# Processing male file 750/804
# Processing male file 760/804
# Processing male file 770/804
# Processing male file 780/804
# Processing male file 790/804
# Processing male file 800/804
# Total features shape for male: (89440, 39)
# Fitting GMM for male (this may still take a moment)...
# SAVED MODEL: c:\Users\ADMIN\Documents\Voice-based-gender-recognition-using-MFCC-and-GMM\nnCode\models\males.nn

# %%
gender_identifier = GenderIdentifier("TestingData/females", "TestingData/males", "nnCode/models/females.nn", "nnCode/models/males.nn")
gender_identifier.process()
# Out:
# Loading GMM models...
# NN Training Data Shape: (32, 39)
# Training Neural Network...
# Neural Network trained successfully.
# --> TESTING        : f0001_us_f0001_00295.wav
# Model is not converging.  Current: 1318.7371990609777 is not greater than 1318.7505480811265. Delta is -0.013349020148780255
# Model is not converging.  Current: 1353.2686822119663 is not greater than 1353.2687139385253. Delta is -3.172655897287768e-05
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00296.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00297.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00298.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00299.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00300.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00301.wav
# Model is not converging.  Current: 1209.0208334209656 is not greater than 1209.0752723134933. Delta is -0.0544388925277417
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00302.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00303.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00304.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00305.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00306.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00307.wav
# Model is not converging.  Current: 1618.2112627263205 is not greater than 1618.211262742938. Delta is -1.6617605069768615e-08
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00308.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00309.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00310.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Model is not converging.  Current: -inf is not greater than 1075.3696044447731. Delta is -inf
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00311.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00312.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00313.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00314.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00315.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 14 | Male: 2
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00316.wav
# Model is not converging.  Current: 1173.1974762177053 is not greater than 1173.202194884159. Delta is -0.0047186664537548495
# Model is not converging.  Current: 1400.2300191368756 is not greater than 1400.2773339989594. Delta is -0.04731486208379465
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00317.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00318.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00319.wav
# Model is not converging.  Current: 1170.0998873923782 is not greater than 1170.0998895809273. Delta is -2.1885491605644347e-06
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00320.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00321.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00322.wav
# Model is not converging.  Current: 1557.0934390176474 is not greater than 1557.0951731180478. Delta is -0.0017341004004265415
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00323.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00324.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00325.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00326.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00327.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00328.wav
# Model is not converging.  Current: 1740.3749042393417 is not greater than 1740.3755669574866. Delta is -0.0006627181448948249
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00329.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00330.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00331.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00332.wav
# Model is not converging.  Current: 1885.6686576409982 is not greater than 1885.6686576678549. Delta is -2.685669642232824e-08
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00333.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00334.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00335.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00336.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00337.wav
# Model is not converging.  Current: 1188.112752179515 is not greater than 1188.1127526653363. Delta is -4.858213742409134e-07
# Model is not converging.  Current: 1330.6170697836849 is not greater than 1330.617070029582. Delta is -2.4589712666056585e-07
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00338.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00339.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00340.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Model is not converging.  Current: 1245.192543891231 is not greater than 1245.2606023326362. Delta is -0.06805844140512818
# Model is not converging.  Current: 1143.5412723252266 is not greater than 1143.5412723427726. Delta is -1.754597178660333e-08
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00341.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00342.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00343.wav
# Model is not converging.  Current: 1375.988075773526 is not greater than 1375.9880758116126. Delta is -3.808668225246947e-08
# Model is not converging.  Current: 1368.8242410214662 is not greater than 1368.824282626833. Delta is -4.1605366959629464e-05
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00344.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00345.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00346.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00347.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00348.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00349.wav
# Model is not converging.  Current: 1487.7558142616444 is not greater than 1487.8412323545972. Delta is -0.08541809295275016
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00350.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00351.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00352.wav
# Model is not converging.  Current: 1496.9137612036031 is not greater than 1496.9198718415635. Delta is -0.006110637960318854
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00353.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00354.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00355.wav
# Model is not converging.  Current: 1451.405326587423 is not greater than 1451.4153740113106. Delta is -0.010047423887726836
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00356.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00357.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00358.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00359.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00360.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00361.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00362.wav
# Model is not converging.  Current: 1137.7457895018574 is not greater than 1137.7458186394854. Delta is -2.9137627961972612e-05
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00363.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00364.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00365.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00366.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00367.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 14 | Male: 2
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00368.wav
# Model is not converging.  Current: 1576.2554616401433 is not greater than 1576.2558462120198. Delta is -0.0003845718765660422
# Model is not converging.  Current: 1216.322211131158 is not greater than 1216.3248719646804. Delta is -0.002660833522440953
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00369.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00370.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00371.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00372.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00373.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00374.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00375.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00376.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00377.wav
# Model is not converging.  Current: 1909.9307059019095 is not greater than 1909.9591342475628. Delta is -0.028428345653310316
# Model is not converging.  Current: 1482.616775742914 is not greater than 1482.626795147123. Delta is -0.010019404209060667
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00378.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 15 | Male: 1
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00379.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00380.wav
# Model is not converging.  Current: 1457.5287043612504 is not greater than 1457.5293067892985. Delta is -0.0006024280480687594
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00381.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00382.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 14 | Male: 2
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00383.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00384.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00385.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00386.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00387.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00388.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00389.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00390.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00391.wav
# Fitting a model with 1503 free scalar parameters with only 1482 data points will result in a degenerate solution.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00392.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00393.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00394.wav
# Model is not converging.  Current: 1088.1197783483044 is not greater than 1088.119786742023. Delta is -8.393718644583714e-06
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00395.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00396.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00397.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00398.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00399.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00400.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00401.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00402.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00403.wav
# Model is not converging.  Current: 1226.831084247489 is not greater than 1226.831638920526. Delta is -0.0005546730371861486
# Model is not converging.  Current: 1298.1115018574912 is not greater than 1298.1232794737928. Delta is -0.011777616301515081
# Model is not converging.  Current: 916.1163568938405 is not greater than 916.1163930357643. Delta is -3.61419238288363e-05
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00404.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00405.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00406.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Model is not converging.  Current: -inf is not greater than 1076.4221301031685. Delta is -inf
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00407.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00408.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00409.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00410.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00411.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00412.wav
# Model is not converging.  Current: 1138.814376412407 is not greater than 1138.8697024043183. Delta is -0.055325991911331585
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00413.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00414.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00415.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00416.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00417.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00418.wav
# Model is not converging.  Current: 1540.3211107649652 is not greater than 1540.3215944446972. Delta is -0.00048367973204221926
# Model is not converging.  Current: 1072.074671672003 is not greater than 1072.0746717120269. Delta is -4.002390596724581e-08
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00419.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00420.wav
# Model is not converging.  Current: 1564.8163396437774 is not greater than 1564.820444027679. Delta is -0.004104383901676556
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00421.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00422.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00423.wav
# Model is not converging.  Current: 1456.7295683397908 is not greater than 1456.736549774987. Delta is -0.006981435196166785
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00424.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00425.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00426.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00427.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00428.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00429.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00430.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00431.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00432.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00433.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00434.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 14 | Male: 2
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00435.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00436.wav
# Model is not converging.  Current: 1201.7211808370519 is not greater than 1201.7240916811236. Delta is -0.0029108440717209305
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 13 | Male: 3
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00437.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00438.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 14 | Male: 2
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00439.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00440.wav
# Model is not converging.  Current: 914.5355360557841 is not greater than 914.5355383927575. Delta is -2.3369734662992414e-06
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00441.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0001_us_f0001_00442.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 11 | Male: 5
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00268.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00269.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00270.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00271.wav
# Model is not converging.  Current: 1085.990560728731 is not greater than 1086.054456886281. Delta is -0.06389615755006162
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00272.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00273.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00274.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00275.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00276.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00277.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00278.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00279.wav
# Model is not converging.  Current: 1548.485935520816 is not greater than 1548.5323779457901. Delta is -0.04644242497420237
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 10 | Male: 6
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00280.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00281.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 9 | Male: 7
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00282.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00283.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00284.wav
# Model is not converging.  Current: 1120.6778138308314 is not greater than 1120.6778407911213. Delta is -2.6960289915223257e-05
# + EXPECTATION      : female
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00285.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
#    Votes -> Female: 12 | Male: 4
# ----------------------------------------------------
# --> TESTING        : f0002_us_f0002_00286.wav
# + EXPECTATION      : female
# + IDENTIFICATION   : female
# ...
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00119.wav
# Model is not converging.  Current: 1376.646519415748 is not greater than 1376.6544961291884. Delta is -0.007976713440484673
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00120.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00121.wav
# Model is not converging.  Current: 1550.2737961444252 is not greater than 1550.2737966825816. Delta is -5.38156427865033e-07
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00122.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00123.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00124.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00125.wav
# Model is not converging.  Current: 1254.381473380793 is not greater than 1254.3912617544318. Delta is -0.009788373638684789
# Model is not converging.  Current: 1342.602285298889 is not greater than 1342.617440212048. Delta is -0.015154913158994532
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00126.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00127.wav
# Model is not converging.  Current: 1871.9914640527006 is not greater than 1871.99146407479. Delta is -2.2089352569309995e-08
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00128.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00129.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00130.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00131.wav
# Model is not converging.  Current: 1774.3605093111255 is not greater than 1774.361844855719. Delta is -0.0013355445935303578
# Model is not converging.  Current: 1291.1233319898088 is not greater than 1291.1242882150605. Delta is -0.0009562252516843728
# Model is not converging.  Current: 2498.5238293584116 is not greater than 2498.5304623701104. Delta is -0.006633011698795599
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00132.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00133.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00134.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00135.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00136.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00137.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00138.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00139.wav
# Model is not converging.  Current: 1622.596833222301 is not greater than 1622.5971029100042. Delta is -0.00026968770316671
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00140.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00141.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00142.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00143.wav
# Model is not converging.  Current: 2123.1404194152556 is not greater than 2123.2920331856703. Delta is -0.15161377041476953
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00144.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00145.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Model is not converging.  Current: -inf is not greater than 2295.8811710400087. Delta is -inf
# Model is not converging.  Current: 2238.450999403698 is not greater than 2238.703975940078. Delta is -0.25297653638017437
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00146.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00147.wav
# Model is not converging.  Current: 2089.0280924420745 is not greater than 2089.0280925031. Delta is -6.102573024691083e-08
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00148.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00149.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00150.wav
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00151.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00152.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00153.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 6 | Male: 10
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00154.wav
# Model is not converging.  Current: 1594.8253933137748 is not greater than 1594.8254217058952. Delta is -2.8392120384523878e-05
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00155.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 8 | Male: 8
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00156.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00157.wav
# Model is not converging.  Current: 2444.218997926796 is not greater than 2444.823450780246. Delta is -0.6044528534498568
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00158.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00159.wav
# Model is not converging.  Current: 1629.8385574792096 is not greater than 1629.8517909087843. Delta is -0.013233429574711408
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# Some rows of transmat_ have zero sum because no transition from the state was ever observed.
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00160.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00161.wav
# Model is not converging.  Current: 1533.0050733204537 is not greater than 1533.0050985259656. Delta is -2.5205511974490946e-05
# + EXPECTATION      : male
# + IDENTIFICATION   : female
#    Votes -> Female: 16 | Male: 0
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00162.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00163.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00164.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00165.wav
# Model is not converging.  Current: 2021.0916031210834 is not greater than 2021.4167551182413. Delta is -0.3251519971579455
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00166.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00167.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00168.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 7 | Male: 9
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00169.wav
# Model is not converging.  Current: 2186.2129272755756 is not greater than 2186.213750435063. Delta is -0.0008231594874814618
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 3 | Male: 13
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00170.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 5 | Male: 11
# ----------------------------------------------------
# --> TESTING        : m0004_us_m0004_00171.wav
# + EXPECTATION      : male
# + IDENTIFICATION   : male
#    Votes -> Female: 4 | Male: 12
# ----------------------------------------------------
# *** Accuracy = 85.324% ***
