# %%
import os
import urllib.request 
import numpy
import scipy
import pandas
import sklearn
import hmmlearn

# %%
# !pip install pandas hmmlearn pydub SpeechRecognition python_speech_features librosa soundfile keras tensorflow
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
## Import files:
# hmmCode/DataManager.py
# hmmCode/ModelsTrainer.py
# hmmCode/GenderIdentifier.py

from nnCode.DataManager import *
from nnCode.ModelsTrainer import *
from nnCode.GenderIdentifier import *

# %%
# get data
# data_manager = DataManager("SLR45.tgz")
# data_manager.manage()
# train models
models_trainer = ModelsTrainer("TrainingData/females", "TrainingData/males")
models_trainer.process()
# Out:
# --> TESTING        : f0001_us_f0001_00001.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00002.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00003.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00004.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00005.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00006.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00007.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00008.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00009.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00010.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00011.wav
# Detected Gender Label: female
# --> TESTING        : f0001_us_f0001_00012.wav
# Detected Gender Label: female
# ...

# %%
gender_identifier = GenderIdentifier("TestingData/females", "TestingData/males", "females.nn", "males.nn")
gender_identifier.process()
# Out:
# (31472, 39) (31472,)
# Epoch 1/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5912 - loss: 0.6780
# Epoch 2/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 3/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 4/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 5/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5913 - loss: 0.6765
# --> TESTING        : f0001_us_f0001_00295.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00296.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00297.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00298.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00299.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00300.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00301.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00302.wav
# (16, 39)
# ...

# %%
gender_identifier = GenderIdentifier("TestingData/females", "TestingData/males", "females.nn", "males.nn")
gender_identifier.process()
# Out:
# (31472, 39) (31472,)
# Epoch 1/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 899us/step - accuracy: 0.5911 - loss: 0.6779
# Epoch 2/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 927us/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 3/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 875us/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 4/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 866us/step - accuracy: 0.5913 - loss: 0.6765
# Epoch 5/5
# 984/984 ━━━━━━━━━━━━━━━━━━━━ 1s 881us/step - accuracy: 0.5913 - loss: 0.6765
# --> TESTING        : f0001_us_f0001_00295.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00296.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00297.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00298.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00299.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00300.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00301.wav
# (16, 39)
# Error
# --> TESTING        : f0001_us_f0001_00302.wav
# ...
